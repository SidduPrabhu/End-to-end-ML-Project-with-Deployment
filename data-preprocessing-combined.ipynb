# %%
import numpy as np
import pandas as pd

# %%
flats = pd.read_csv('flats_cleaned.csv')
houses = pd.read_csv('house_cleaned.csv')

# %%
flats.shape
# Out:
# (2997, 20)

# %%
houses.shape
# Out:
# (964, 20)

# %%
# Concatinating two dataframes into one dataframe
df = pd.concat([flats,houses],ignore_index=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                       property_name property_type  \
# 0               2 BHK Flat in Sohna          flat
# 1   1 BHK Flat in Sector 81 Gurgaon          flat
# 2   3 BHK Flat in Sector 65 Gurgaon          flat
# 3  2 BHK Flat in Sector 88B Gurgaon          flat
# 4  3 BHK Flat in Sector 37D Gurgaon          flat
#
#                             society  price  price_per_sqft    area  \
# 0            breez global hill view   0.32          5776.0   554.0
# 1           signature global synera   0.38          9500.0   400.0
# 2  emaar mgf emerald floors premier   2.35         14242.0  1650.0
# 3                 vatika xpressions   1.10          8148.0  1350.0
# 4                        bptp terra   1.72          7850.0  2191.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                     Carpet area: 554 (51.47 sq.m.)        2         2
# 1                     Carpet area: 400 (37.16 sq.m.)        1         1
# 2                   Carpet area: 1650 (153.29 sq.m.)        3         3
# 3  Built Up area: 1350 (125.42 sq.m.)Carpet area:...        2         4
# 4             Super Built up area 2191(203.55 sq.m.)        3         3
#
#   balcony           additionalRoom  \
# 0       2            not available
# 1       2            not available
# 2       3  study room,servant room
# 3      3+               study room
# 4      3+             servant room
#
#                                            address  floorNum      facing  \
# 0                    1905, Sohna, Gurgaon, Haryana      19.0       North
# 1         503, Sector 81 Gurgaon, Gurgaon, Haryana       3.0  South-West
# 2         698, Sector 65 Gurgaon, Gurgaon, Haryana       3.0        East
# 3       H 23, Sector 88B Gurgaon, Gurgaon, Haryana       2.0  North-East
# 4  9th Floor, Sector 37D Gurgaon, Gurgaon, Haryana      10.0  South-East
#
#         agePossession                                    nearbyLocations  \
# 0     1 to 5 Year Old  ['Huda City Centre', 'Omaxe City Centre', 'Nin...
# 1     1 to 5 Year Old  ['Sapphire 83 Mall', 'Delhi Jaipur Expressway'...
# 2     1 to 5 Year Old  ['WorldMark Gurgaon', 'Sohna Road', 'Golf Cour...
# 3  Under Construction  ['Dwarka Expressway', 'Adarsh public school,Ga...
# 4     1 to 5 Year Old  ['Airia Mall', 'Dwarka Expressway', 'Golf Cour...
#
#                                          description  \
# 0  Sohna is a peripheral area on the southern sid...
# 1  Signature global synera is one of gurgaon's mo...
# 2  Emaar mgf emerald floors premier is one of gur...
# 3  We are the proud owners of this 2 bhk apartmen...
# 4  Check out this 3 bhk apartment for sale in bpt...
#
#                                       furnishDetails  \
# 0  ['2 Wardrobe', '2 Bed', '1 Water Purifier', '4...
# 1                                                NaN
# 2  ['3 Wardrobe', '7 Fan', '1 Exhaust Fan', '3 Ge...
# 3                                                NaN
# 4  ['5 Fan', '5 Light', '3 AC', 'No Bed', 'No Chi...
#
#                                             features  \
# 0  ['Power Back-up', 'Lift(s)', 'Maintenance Staf...
# 1  ['Lift(s)', 'Maintenance Staff', 'False Ceilin...
# 2  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 3  ['Feng Shui / Vaastu Compliant', 'Intercom Fac...
# 4  ['Lift(s)', 'Swimming Pool', 'Park', 'Fitness ...
#
#                                               rating
# 0  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 1  ['Green Area4 out of 5', 'Construction3 out of...
# 2  ['Green Area4.5 out of 5', 'Construction5 out ...
# 3                                                NaN
# 4  ['Green Area4.5 out of 5', 'Construction4.5 ou...

# %%
df.shape
# Out:
# (3961, 20)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3961 entries, 0 to 3960
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_name    3961 non-null   object
#  1   property_type    3961 non-null   object
#  2   society          3960 non-null   object
#  3   price            3941 non-null   float64
#  4   price_per_sqft   3941 non-null   float64
#  5   area             3941 non-null   float64
#  6   areaWithType     3961 non-null   object
#  7   bedRoom          3961 non-null   int64
#  8   bathroom         3961 non-null   int64
#  9   balcony          3961 non-null   object
#  10  additionalRoom   3961 non-null   object
#  11  address          3950 non-null   object
#  12  floorNum         3940 non-null   float64
#  13  facing           2784 non-null   object
#  14  agePossession    3960 non-null   object
#  15  nearbyLocations  3754 non-null   object
#  16  description      3961 non-null   object
#  17  furnishDetails   2929 non-null   object
#  18  features         3252 non-null   object
#  19  rating           3511 non-null   object
# dtypes: float64(4), int64(2), object(14)
# memory usage: 619.0+ KB

# %%
df.isnull().sum()
# Out:
# property_name         0
# property_type         0
# society               1
# price                20
# price_per_sqft       20
# area                 20
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom        0
# address              11
# floorNum             21
# facing             1177
# agePossession         1
# nearbyLocations     207
# description           0
# furnishDetails     1032
# features            709
# rating              450
# dtype: int64

# %%
df.head()
# Out:
#                       property_name property_type  \
# 0               2 BHK Flat in Sohna          flat
# 1   1 BHK Flat in Sector 81 Gurgaon          flat
# 2   3 BHK Flat in Sector 65 Gurgaon          flat
# 3  2 BHK Flat in Sector 88B Gurgaon          flat
# 4  3 BHK Flat in Sector 37D Gurgaon          flat
#
#                             society  price  price_per_sqft    area  \
# 0            breez global hill view   0.32          5776.0   554.0
# 1           signature global synera   0.38          9500.0   400.0
# 2  emaar mgf emerald floors premier   2.35         14242.0  1650.0
# 3                 vatika xpressions   1.10          8148.0  1350.0
# 4                        bptp terra   1.72          7850.0  2191.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                     Carpet area: 554 (51.47 sq.m.)        2         2
# 1                     Carpet area: 400 (37.16 sq.m.)        1         1
# 2                   Carpet area: 1650 (153.29 sq.m.)        3         3
# 3  Built Up area: 1350 (125.42 sq.m.)Carpet area:...        2         4
# 4             Super Built up area 2191(203.55 sq.m.)        3         3
#
#   balcony           additionalRoom  \
# 0       2            not available
# 1       2            not available
# 2       3  study room,servant room
# 3      3+               study room
# 4      3+             servant room
#
#                                            address  floorNum      facing  \
# 0                    1905, Sohna, Gurgaon, Haryana      19.0       North
# 1         503, Sector 81 Gurgaon, Gurgaon, Haryana       3.0  South-West
# 2         698, Sector 65 Gurgaon, Gurgaon, Haryana       3.0        East
# 3       H 23, Sector 88B Gurgaon, Gurgaon, Haryana       2.0  North-East
# 4  9th Floor, Sector 37D Gurgaon, Gurgaon, Haryana      10.0  South-East
#
#         agePossession                                    nearbyLocations  \
# 0     1 to 5 Year Old  ['Huda City Centre', 'Omaxe City Centre', 'Nin...
# 1     1 to 5 Year Old  ['Sapphire 83 Mall', 'Delhi Jaipur Expressway'...
# 2     1 to 5 Year Old  ['WorldMark Gurgaon', 'Sohna Road', 'Golf Cour...
# 3  Under Construction  ['Dwarka Expressway', 'Adarsh public school,Ga...
# 4     1 to 5 Year Old  ['Airia Mall', 'Dwarka Expressway', 'Golf Cour...
#
#                                          description  \
# 0  Sohna is a peripheral area on the southern sid...
# 1  Signature global synera is one of gurgaon's mo...
# 2  Emaar mgf emerald floors premier is one of gur...
# 3  We are the proud owners of this 2 bhk apartmen...
# 4  Check out this 3 bhk apartment for sale in bpt...
#
#                                       furnishDetails  \
# 0  ['2 Wardrobe', '2 Bed', '1 Water Purifier', '4...
# 1                                                NaN
# 2  ['3 Wardrobe', '7 Fan', '1 Exhaust Fan', '3 Ge...
# 3                                                NaN
# 4  ['5 Fan', '5 Light', '3 AC', 'No Bed', 'No Chi...
#
#                                             features  \
# 0  ['Power Back-up', 'Lift(s)', 'Maintenance Staf...
# 1  ['Lift(s)', 'Maintenance Staff', 'False Ceilin...
# 2  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 3  ['Feng Shui / Vaastu Compliant', 'Intercom Fac...
# 4  ['Lift(s)', 'Swimming Pool', 'Park', 'Fitness ...
#
#                                               rating
# 0  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 1  ['Green Area4 out of 5', 'Construction3 out of...
# 2  ['Green Area4.5 out of 5', 'Construction5 out ...
# 3                                                NaN
# 4  ['Green Area4.5 out of 5', 'Construction4.5 ou...

# %%
df.insert(loc=3,column='sector',value=df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon','').str.strip())

# %%
df.head()
# Out:
#                       property_name property_type  \
# 0               2 BHK Flat in Sohna          flat
# 1   1 BHK Flat in Sector 81 Gurgaon          flat
# 2   3 BHK Flat in Sector 65 Gurgaon          flat
# 3  2 BHK Flat in Sector 88B Gurgaon          flat
# 4  3 BHK Flat in Sector 37D Gurgaon          flat
#
#                             society      sector  price  price_per_sqft  \
# 0            breez global hill view       Sohna   0.32          5776.0
# 1           signature global synera   Sector 81   0.38          9500.0
# 2  emaar mgf emerald floors premier   Sector 65   2.35         14242.0
# 3                 vatika xpressions  Sector 88B   1.10          8148.0
# 4                        bptp terra  Sector 37D   1.72          7850.0
#
#      area                                       areaWithType  bedRoom  \
# 0   554.0                     Carpet area: 554 (51.47 sq.m.)        2
# 1   400.0                     Carpet area: 400 (37.16 sq.m.)        1
# 2  1650.0                   Carpet area: 1650 (153.29 sq.m.)        3
# 3  1350.0  Built Up area: 1350 (125.42 sq.m.)Carpet area:...        2
# 4  2191.0             Super Built up area 2191(203.55 sq.m.)        3
#
#    bathroom  ...           additionalRoom  \
# 0         2  ...            not available
# 1         1  ...            not available
# 2         3  ...  study room,servant room
# 3         4  ...               study room
# 4         3  ...             servant room
#
#                                            address floorNum      facing  \
# 0                    1905, Sohna, Gurgaon, Haryana     19.0       North
# 1         503, Sector 81 Gurgaon, Gurgaon, Haryana      3.0  South-West
# 2         698, Sector 65 Gurgaon, Gurgaon, Haryana      3.0        East
# 3       H 23, Sector 88B Gurgaon, Gurgaon, Haryana      2.0  North-East
# 4  9th Floor, Sector 37D Gurgaon, Gurgaon, Haryana     10.0  South-East
#
#         agePossession                                    nearbyLocations  \
# 0     1 to 5 Year Old  ['Huda City Centre', 'Omaxe City Centre', 'Nin...
# 1     1 to 5 Year Old  ['Sapphire 83 Mall', 'Delhi Jaipur Expressway'...
# 2     1 to 5 Year Old  ['WorldMark Gurgaon', 'Sohna Road', 'Golf Cour...
# 3  Under Construction  ['Dwarka Expressway', 'Adarsh public school,Ga...
# 4     1 to 5 Year Old  ['Airia Mall', 'Dwarka Expressway', 'Golf Cour...
#
#                                          description  \
# 0  Sohna is a peripheral area on the southern sid...
# 1  Signature global synera is one of gurgaon's mo...
# 2  Emaar mgf emerald floors premier is one of gur...
# 3  We are the proud owners of this 2 bhk apartmen...
# 4  Check out this 3 bhk apartment for sale in bpt...
#
#                                       furnishDetails  \
# 0  ['2 Wardrobe', '2 Bed', '1 Water Purifier', '4...
# 1                                                NaN
# 2  ['3 Wardrobe', '7 Fan', '1 Exhaust Fan', '3 Ge...
# 3                                                NaN
# 4  ['5 Fan', '5 Light', '3 AC', 'No Bed', 'No Chi...
#
#                                             features  \
# 0  ['Power Back-up', 'Lift(s)', 'Maintenance Staf...
# 1  ['Lift(s)', 'Maintenance Staff', 'False Ceilin...
# 2  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 3  ['Feng Shui / Vaastu Compliant', 'Intercom Fac...
# 4  ['Lift(s)', 'Swimming Pool', 'Park', 'Fitness ...
#
#                                               rating
# 0  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 1  ['Green Area4 out of 5', 'Construction3 out of...
# 2  ['Green Area4.5 out of 5', 'Construction5 out ...
# 3                                                NaN
# 4  ['Green Area4.5 out of 5', 'Construction4.5 ou...
#
# [5 rows x 21 columns]

# %%
df['sector'] = df['sector'].str.lower()

# %%
df.head()
# Out:
#                       property_name property_type  \
# 0               2 BHK Flat in Sohna          flat
# 1   1 BHK Flat in Sector 81 Gurgaon          flat
# 2   3 BHK Flat in Sector 65 Gurgaon          flat
# 3  2 BHK Flat in Sector 88B Gurgaon          flat
# 4  3 BHK Flat in Sector 37D Gurgaon          flat
#
#                             society      sector  price  price_per_sqft  \
# 0            breez global hill view       sohna   0.32          5776.0
# 1           signature global synera   sector 81   0.38          9500.0
# 2  emaar mgf emerald floors premier   sector 65   2.35         14242.0
# 3                 vatika xpressions  sector 88b   1.10          8148.0
# 4                        bptp terra  sector 37d   1.72          7850.0
#
#      area                                       areaWithType  bedRoom  \
# 0   554.0                     Carpet area: 554 (51.47 sq.m.)        2
# 1   400.0                     Carpet area: 400 (37.16 sq.m.)        1
# 2  1650.0                   Carpet area: 1650 (153.29 sq.m.)        3
# 3  1350.0  Built Up area: 1350 (125.42 sq.m.)Carpet area:...        2
# 4  2191.0             Super Built up area 2191(203.55 sq.m.)        3
#
#    bathroom  ...           additionalRoom  \
# 0         2  ...            not available
# 1         1  ...            not available
# 2         3  ...  study room,servant room
# 3         4  ...               study room
# 4         3  ...             servant room
#
#                                            address floorNum      facing  \
# 0                    1905, Sohna, Gurgaon, Haryana     19.0       North
# 1         503, Sector 81 Gurgaon, Gurgaon, Haryana      3.0  South-West
# 2         698, Sector 65 Gurgaon, Gurgaon, Haryana      3.0        East
# 3       H 23, Sector 88B Gurgaon, Gurgaon, Haryana      2.0  North-East
# 4  9th Floor, Sector 37D Gurgaon, Gurgaon, Haryana     10.0  South-East
#
#         agePossession                                    nearbyLocations  \
# 0     1 to 5 Year Old  ['Huda City Centre', 'Omaxe City Centre', 'Nin...
# 1     1 to 5 Year Old  ['Sapphire 83 Mall', 'Delhi Jaipur Expressway'...
# 2     1 to 5 Year Old  ['WorldMark Gurgaon', 'Sohna Road', 'Golf Cour...
# 3  Under Construction  ['Dwarka Expressway', 'Adarsh public school,Ga...
# 4     1 to 5 Year Old  ['Airia Mall', 'Dwarka Expressway', 'Golf Cour...
#
#                                          description  \
# 0  Sohna is a peripheral area on the southern sid...
# 1  Signature global synera is one of gurgaon's mo...
# 2  Emaar mgf emerald floors premier is one of gur...
# 3  We are the proud owners of this 2 bhk apartmen...
# 4  Check out this 3 bhk apartment for sale in bpt...
#
#                                       furnishDetails  \
# 0  ['2 Wardrobe', '2 Bed', '1 Water Purifier', '4...
# 1                                                NaN
# 2  ['3 Wardrobe', '7 Fan', '1 Exhaust Fan', '3 Ge...
# 3                                                NaN
# 4  ['5 Fan', '5 Light', '3 AC', 'No Bed', 'No Chi...
#
#                                             features  \
# 0  ['Power Back-up', 'Lift(s)', 'Maintenance Staf...
# 1  ['Lift(s)', 'Maintenance Staff', 'False Ceilin...
# 2  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 3  ['Feng Shui / Vaastu Compliant', 'Intercom Fac...
# 4  ['Lift(s)', 'Swimming Pool', 'Park', 'Fitness ...
#
#                                               rating
# 0  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 1  ['Green Area4 out of 5', 'Construction3 out of...
# 2  ['Green Area4.5 out of 5', 'Construction5 out ...
# 3                                                NaN
# 4  ['Green Area4.5 out of 5', 'Construction4.5 ou...
#
# [5 rows x 21 columns]

# %%
df['sector'].value_counts()
# Out:
# sohna                                                        163
# sector 102                                                   113
# sector 85                                                    110
# sector 92                                                    104
# sector 69                                                     94
#                                                             ...
# near khandsa road                                              1
# devi lal colony gali no 12 gurgaon nr omkar public school      1
# kanahi                                                         1
# godrej aria , sector 79 ,                                      1
# lucknow                                                        1
# Name: sector, Length: 301, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('dharam colony','sector 12')
df['sector'] = df['sector'].str.replace('krishna colony','sector 7')
df['sector'] = df['sector'].str.replace('suncity','sector 54')
df['sector'] = df['sector'].str.replace('prem nagar','sector 13')
df['sector'] = df['sector'].str.replace('mg road','sector 28')
df['sector'] = df['sector'].str.replace('gandhi nagar','sector 28')
df['sector'] = df['sector'].str.replace('laxmi garden','sector 11')
df['sector'] = df['sector'].str.replace('shakti nagar','sector 11')

# %%
df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')

# %%
df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')

# %%
df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')

# %%
df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')

# %%
df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')

# %%
df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')

# %%
a = df['sector'].value_counts()[df['sector'].value_counts() >= 3]
df = df[df['sector'].isin(a.index)]

# %%
df['sector'].value_counts()
# Out:
# sohna road     163
# sector 102     113
# sector 85      110
# sector 92      104
# sector 69       94
#               ...
# sector 17b       3
# sector 17a       3
# sector 73        3
# sector 15        3
# maruti kunj      3
# Name: sector, Length: 131, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')

# %%
df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')

# %%
df[df['sector'] == 'new']
# Out:
#                   property_name property_type                       society  \
# 2181  2 BHK Flat in New Gurgaon          flat                   green court
# 3202  4 BHK Flat in New Gurgaon          flat                    sare homes
# 3555  2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
# 3704  4 BHK Flat in New Gurgaon          flat                        dlf 76
#
#      sector  price  price_per_sqft    area  \
# 2181    new   0.38          5507.0   690.0
# 3202    new   0.85          4786.0  1776.0
# 3555    new   0.67          5583.0  1200.0
# 3704    new   4.00         11428.0  3500.0
#
#                                 areaWithType  bedRoom  bathroom  ...  \
# 2181           Carpet area: 690 (64.1 sq.m.)        2         2  ...
# 3202     Super Built up area 1776(165 sq.m.)        4         4  ...
# 3555  Super Built up area 1200(111.48 sq.m.)        2         2  ...
# 3704        Carpet area: 3500 (325.16 sq.m.)        4         4  ...
#
#                additionalRoom                        address floorNum  facing  \
# 2181            not available  New Gurgaon, Gurgaon, Haryana      7.0     NaN
# 3202            not available  New Gurgaon, Gurgaon, Haryana      3.0     NaN
# 3555            not available  New Gurgaon, Gurgaon, Haryana      3.0     NaN
# 3704  study room,servant room  New Gurgaon, Gurgaon, Haryana      4.0     NaN
#
#            agePossession                                    nearbyLocations  \
# 2181  Under Construction  ['Ing bank ATM', 'Dcb bank ATM', 'Indus ind ba...
# 3202    5 to 10 Year Old  ['Columbia Asia Hospital', 'Apex Multi Special...
# 3555     1 to 5 Year Old  ['Shri Balaji Hospital and Trauma Center', 'S....
# 3704            Jun 2027  ['Shri Balaji Hospital and Trauma Center', 'S....
#
#                                             description  \
# 2181  We are the proud owners of this 2 bhk apartmen...
# 3202  Located in the popular residential address of ...
# 3555  Check out this 2 bhk apartment for sale in tak...
# 3704  This lovely 4 bhk apartment/flat in new gurgao...
#
#                                          furnishDetails  \
# 2181                                                 []
# 3202                                                 []
# 3555                                                 []
# 3704  ['6 Wardrobe', '1 Fridge', '8 Fan', '1 Exhaust...
#
#                                                features rating
# 2181  ['Intercom Facility', 'Lift(s)', 'Maintenance ...    NaN
# 3202                                                NaN    NaN
# 3555  ['Lift(s)', 'Swimming Pool', 'Visitor Parking'...    NaN
# 3704  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...    NaN
#
# [4 rows x 21 columns]

# %%
df.loc[2181,'sector'] = 'sector 37'
df.loc[3202,'sector'] = 'sector 92'
df.loc[3555,'sector'] = 'sector 90'
df.loc[3704,'sector'] = 'sector 76'

# %%
df[df['sector'] == 'new sector 2']
# Out:
#                                     property_name property_type  \
# 454   3 Bedroom House for sale in New Palam Vihar         house
# 1912                2 BHK Flat in New Palam Vihar          flat
# 2000  2 Bedroom House for sale in New Palam Vihar         house
# 2076                2 BHK Flat in New Palam Vihar          flat
# 2901                2 BHK Flat in New Palam Vihar          flat
#
#                   society        sector  price  price_per_sqft    area  \
# 454           independent  new sector 2   1.00          8796.0  1137.0
# 1912  ompee k s residency  new sector 2   1.60         26936.0   594.0
# 2000              my home  new sector 2   0.34         12592.0   270.0
# 2076              my home  new sector 2   0.22          4400.0   500.0
# 2901              my home  new sector 2   0.28          3166.0   884.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 454   Plot area 120(100.34 sq.m.)Built Up area: 120 ...        3         2
# 1912                      Carpet area: 66 (55.18 sq.m.)        2         2
# 2000                         Plot area 270(25.08 sq.m.)        2         2
# 2076                     Carpet area: 500 (46.45 sq.m.)        2         2
# 2901                     Carpet area: 900 (83.61 sq.m.)        2         1
#
#       ... additionalRoom                                            address  \
# 454   ...     pooja room  Q-148, New Palam Vihar, Phase-2, Near Royal Oa...
# 1912  ...  not available                  New Palam Vihar, Gurgaon, Haryana
# 2000  ...  not available         Ez-19 A, New Palam Vihar, Gurgaon, Haryana
# 2076  ...  not available                  New Palam Vihar, Gurgaon, Haryana
# 2901  ...         others         F 150/b, New Palam Vihar, Gurgaon, Haryana
#
#      floorNum  facing     agePossession  \
# 454       1.0   North      10+ Year Old
# 1912      1.0     NaN   1 to 5 Year Old
# 2000      3.0    West  5 to 10 Year Old
# 2076      1.0     NaN   0 to 1 Year Old
# 2901      2.0     NaN   1 to 5 Year Old
#
#                                         nearbyLocations  \
# 454   ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 1912  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2000  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2076  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2901  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                             description  \
# 454   Ground and first floor, Ground floor: Ground f...
# 1912  We are the proud owners of this 2 bhk apartmen...
# 2000  There are availability of various facilities l...
# 2076  Cctv surveillance are provided here. There is ...
# 2901  2 bhk room with wooden coverd ,1 drawing room,...
#
#                                          furnishDetails  \
# 454                                                 NaN
# 1912                                                NaN
# 2000  ['1 Wardrobe', '3 Fan', '6 Light', 'No AC', 'N...
# 2076  ['3 Fan', '1 Exhaust Fan', '15 Light', '1 Modu...
# 2901  ['3 Wardrobe', '5 Light', '1 Chimney', '1 Modu...
#
#                                           features  \
# 454                                            NaN
# 1912                                           NaN
# 2000  ['Water Storage', 'Park', 'Visitor Parking']
# 2076                                           NaN
# 2901                     ['Water Storage', 'Park']
#
#                                                  rating
# 454   ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 1912  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2000  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 2076  ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...
# 2901  ['Environment4 out of 5', 'Safety4 out of 5', ...
#
# [5 rows x 21 columns]

# %%
df.loc[[454,1912,2000,2076,2901],'sector'] = 'sector 110'

# %%
df.shape
# Out:
# (3803, 21)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#                       property_name property_type  \
# 0               2 BHK Flat in Sohna          flat
# 1   1 BHK Flat in Sector 81 Gurgaon          flat
# 2   3 BHK Flat in Sector 65 Gurgaon          flat
# 3  2 BHK Flat in Sector 88B Gurgaon          flat
# 4  3 BHK Flat in Sector 37D Gurgaon          flat
#
#                             society      sector  price  price_per_sqft  \
# 0            breez global hill view  sohna road   0.32          5776.0
# 1           signature global synera   sector 81   0.38          9500.0
# 2  emaar mgf emerald floors premier   sector 65   2.35         14242.0
# 3                 vatika xpressions  sector 88b   1.10          8148.0
# 4                        bptp terra  sector 37d   1.72          7850.0
#
#      area                                       areaWithType  bedRoom  \
# 0   554.0                     Carpet area: 554 (51.47 sq.m.)        2
# 1   400.0                     Carpet area: 400 (37.16 sq.m.)        1
# 2  1650.0                   Carpet area: 1650 (153.29 sq.m.)        3
# 3  1350.0  Built Up area: 1350 (125.42 sq.m.)Carpet area:...        2
# 4  2191.0             Super Built up area 2191(203.55 sq.m.)        3
#
#    bathroom  ...           additionalRoom  \
# 0         2  ...            not available
# 1         1  ...            not available
# 2         3  ...  study room,servant room
# 3         4  ...               study room
# 4         3  ...             servant room
#
#                                            address floorNum      facing  \
# 0                    1905, Sohna, Gurgaon, Haryana     19.0       North
# 1         503, Sector 81 Gurgaon, Gurgaon, Haryana      3.0  South-West
# 2         698, Sector 65 Gurgaon, Gurgaon, Haryana      3.0        East
# 3       H 23, Sector 88B Gurgaon, Gurgaon, Haryana      2.0  North-East
# 4  9th Floor, Sector 37D Gurgaon, Gurgaon, Haryana     10.0  South-East
#
#         agePossession                                    nearbyLocations  \
# 0     1 to 5 Year Old  ['Huda City Centre', 'Omaxe City Centre', 'Nin...
# 1     1 to 5 Year Old  ['Sapphire 83 Mall', 'Delhi Jaipur Expressway'...
# 2     1 to 5 Year Old  ['WorldMark Gurgaon', 'Sohna Road', 'Golf Cour...
# 3  Under Construction  ['Dwarka Expressway', 'Adarsh public school,Ga...
# 4     1 to 5 Year Old  ['Airia Mall', 'Dwarka Expressway', 'Golf Cour...
#
#                                          description  \
# 0  Sohna is a peripheral area on the southern sid...
# 1  Signature global synera is one of gurgaon's mo...
# 2  Emaar mgf emerald floors premier is one of gur...
# 3  We are the proud owners of this 2 bhk apartmen...
# 4  Check out this 3 bhk apartment for sale in bpt...
#
#                                       furnishDetails  \
# 0  ['2 Wardrobe', '2 Bed', '1 Water Purifier', '4...
# 1                                                NaN
# 2  ['3 Wardrobe', '7 Fan', '1 Exhaust Fan', '3 Ge...
# 3                                                NaN
# 4  ['5 Fan', '5 Light', '3 AC', 'No Bed', 'No Chi...
#
#                                             features  \
# 0  ['Power Back-up', 'Lift(s)', 'Maintenance Staf...
# 1  ['Lift(s)', 'Maintenance Staff', 'False Ceilin...
# 2  ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 3  ['Feng Shui / Vaastu Compliant', 'Intercom Fac...
# 4  ['Lift(s)', 'Swimming Pool', 'Park', 'Fitness ...
#
#                                               rating
# 0  ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 1  ['Green Area4 out of 5', 'Construction3 out of...
# 2  ['Green Area4.5 out of 5', 'Construction5 out ...
# 3                                                NaN
# 4  ['Green Area4.5 out of 5', 'Construction4.5 ou...
#
# [5 rows x 21 columns]

# %%
# features to drop -> property_name, address, description, rating
df.drop(columns=['property_name', 'address', 'description', 'rating'],inplace=True)

# %%
df.sample(5)
# Out:
#      property_type                    society      sector  price  \
# 475           flat           dlf regency park   sector 28   2.35
# 1527          flat                tulip lemon   sector 69   0.60
# 1486          flat     vatika lifestyle homes   sector 83   1.15
# 2125          flat     conscient heritage max  sector 102   1.82
# 1539          flat  orris aster court premier   sector 85   1.20
#
#       price_per_sqft    area  \
# 475          13224.0  1777.0
# 1527         10000.0   600.0
# 1486          8214.0  1400.0
# 2125          9011.0  2020.0
# 1539          5660.0  2120.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 475   Super Built up area 1777(165.09 sq.m.)Built Up...        3         4
# 1527                     Carpet area: 600 (55.74 sq.m.)        2         1
# 1486  Super Built up area 1832(170.2 sq.m.)Carpet ar...        3         3
# 2125             Super Built up area 1942(180.42 sq.m.)        3         4
# 1539  Super Built up area 2120(196.95 sq.m.)Built Up...        3         4
#
#      balcony additionalRoom  floorNum      facing     agePossession  \
# 475        3   servant room       8.0  South-East      10+ Year Old
# 1527       1  not available      12.0         NaN   1 to 5 Year Old
# 1486       1  not available       7.0  South-West  5 to 10 Year Old
# 2125      3+   servant room      12.0  North-East   1 to 5 Year Old
# 1539       2   servant room       6.0  North-East   1 to 5 Year Old
#
#                                         nearbyLocations  \
# 475   ['Dlf phase 1 metro station', 'Sector 42-43 me...
# 1527  ['Sri Radhe Krishna Temple', 'Icici bank ATM',...
# 1486  ['Sapphire 83 Mall', 'NH – 08', 'Knowledge Tre...
# 2125  ['Huda Metro Station', 'Ocus Medley Mall', 'Th...
# 1539  ['Propose Metro Station', 'SS Omnia Mall', 'Na...
#
#                                          furnishDetails  \
# 475   ['3 Wardrobe', '5 Fan', '1 Exhaust Fan', '3 Ge...
# 1527  ['2 Wardrobe', '3 Fan', '1 Geyser', '5 Light',...
# 1486  ['3 Wardrobe', '2 Fan', '1 Exhaust Fan', '2 Ge...
# 2125                                                 []
# 1539  ['3 Wardrobe', '1 Modular Kitchen', '1 Chimney...
#
#                                                features
# 475   ['Security / Fire Alarm', 'Power Back-up', 'Fe...
# 1527  ['Piped-gas', 'Security Personnel', 'Shopping ...
# 1486  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 2125  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 1539  ['Lift(s)', 'Maintenance Staff', 'Water Storag...

# %%
# feature engineering required -> areaWithType, additionalRoom, facing, agePossession, furnishDetails, features

# %%
df.duplicated().sum()
# Out:
# 122

# %%
df.to_csv('gurgaon_properties_cleaned_v1.csv',index=False)
